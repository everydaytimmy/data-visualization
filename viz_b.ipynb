# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
booze_df = pd.read_csv('./alcohol.csv')
booze_df.head()
# Out:
#        country  alcconsumption  incomeperperson  suicideper100th  employrate  \
# 0  Afghanistan            0.03              NaN         6.684385   55.700001
# 1      Albania            7.29      1914.996551         7.699330   51.400002
# 2      Algeria            0.69      2231.993335         4.848770   50.500000
# 3      Andorra           10.17     21943.339900         5.362179         NaN
# 4       Angola            5.57      1381.004268        14.554677   75.699997
#
#    urbanrate
# 0      24.04
# 1      46.72
# 2      65.22
# 3      88.92
# 4      56.70

# %%
sns.set()

# %%
filtered = booze_df[(booze_df.alcconsumption >= 2)]

# %%
sns.relplot(data=filtered, y="alcconsumption", x="incomeperperson")

# %%
sns.relplot(data=filtered, y="alcconsumption", x="suicideper100th")

# %%
sns.relplot(data=filtered, y="alcconsumption", x="employrate")
